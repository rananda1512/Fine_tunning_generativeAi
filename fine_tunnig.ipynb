# %% [markdown]
# # Install Lib

# %%
pip install datasets transformers transformers[torch] torch huggingface-hub nltk rouge_score evaluate

# %% [markdown]
# # Make Dataset

# %%
import pandas as pd
plant_disease_data=([
     {"question": "What are Rust for plant",
     "answer": "A rust plant refers to a condition in plants caused by fungal diseases from the order Pucciniales. It is characterized by the appearance of orange, red, or brown spots resembling rust on leaves, stems, or other plant parts. This disease weakens the plant, reducing its growth and productivity, and is commonly found in agricultural crops and ornamental plants."},
    {"question": "What causes yellowing and wilting of leaves on rice plants?",
     "answer": "The disease is caused by the bacterial pathogen Xanthomonas oryzae."},
    {"question": "How can basal rot be controlled in chili plants?",
     "answer": "Use fungicides with mancozeb and ensure proper drainage."},
    {"question": "What are the main symptoms of powdery mildew in grapevines?",
     "answer": "Leaves and fruits are covered with a white, powdery coating."},
    {"question": "What causes brown leaf spots on tomato plants?",
     "answer": "This disease is caused by the fungus Alternaria solani."},
    {"question": "How can Fusarium wilt be prevented in banana plants?",
     "answer": "Use resistant varieties and rotate crops regularly."},
    {"question": "What causes potato plants to experience leaf blight?",
     "answer": "The disease is caused by the fungus Phytophthora infestans."},
    {"question": "How to manage anthracnose in mango plants?",
     "answer": "Apply fungicides containing propineb and prune infected parts."},
    {"question": "What are the initial symptoms of mosaic virus in chili plants?",
     "answer": "Leaves show a mottled pattern of light green and dark green."},
    {"question": "What causes leaf rust in coffee plants?",
     "answer": "The disease is caused by the fungus Hemileia vastatrix."},
    {"question": "How to treat fruit rot in strawberry plants?",
     "answer": "Use fungicides containing boscalid and improve air circulation."},
    {"question": "What causes rust disease in wheat plants?",
     "answer": "The disease is caused by the fungus Puccinia spp., which infects wheat plants."},
    {"question": "How can you prevent rust in soybean plants?",
     "answer": "Apply fungicides at the right time and rotate crops to manage the disease."},
    {"question": "What are the symptoms of rust in rose plants?",
     "answer": "Rust causes yellowish spots on leaves, followed by orange or red pustules."},
    {"question": "What treatment is recommended for apple tree rust?",
     "answer": "Prune infected leaves and apply copper-based fungicides to control the disease."},
    {"question": "How does rust affect the growth of grapevine plants?",
     "answer": "Rust causes the leaves to turn yellow and become deformed, stunting plant growth."},
    {"question": "What causes rust disease in beans?",
     "answer": "Rust in beans is caused by the fungus Uromyces appendiculatus."},
    {"question": "What is the best way to treat rust on ornamental plants?",
     "answer": "Remove and destroy infected leaves, and apply fungicides containing chlorothalonil."},
    {"question": "What are the initial signs of rust on sunflower plants?",
     "answer": "Rust appears as small yellow pustules on the underside of leaves, eventually turning brown."},
    {"question": "How can rust be managed in corn crops?",
     "answer": "Use resistant corn varieties, and apply fungicides when rust is first detected."},
    {"question": "What causes rust on citrus trees?",
     "answer": "The disease is caused by the fungus Puccinia spp. that infects the leaves and fruit of citrus trees."},
    {"question": "How does rust affect tomato plants?",
     "answer": "Rust causes yellowing and dropping of leaves, affecting fruit yield."},
    {"question": "What are the symptoms of rust in grass?",
     "answer": "Rust causes yellow or orange pustules on grass leaves, eventually leading to leaf death."},
    {"question": "How can you treat rust on asparagus?",
     "answer": "Remove infected ferns and apply fungicides like mancozeb."},
    {"question": "What is the best way to prevent rust in fruit trees?",
     "answer": "Maintain proper spacing, remove fallen leaves, and apply preventive fungicides."},
    {"question": "How does rust spread on crops?",
     "answer": "Rust spreads through airborne spores that are carried by wind or rain."},
    {"question": "What causes rust in cucumbers?",
     "answer": "Rust in cucumbers is caused by the fungus Puccinia cucurbitacearum."},
    {"question": "What are the main control methods for rust on peas?",
     "answer": "Use rust-resistant varieties, and apply fungicides at the early signs of infection."},
    {"question": "How do you identify rust in pumpkin plants?",
     "answer": "Rust appears as orange pustules on the underside of pumpkin leaves."},
    {"question": "What causes rust in eucalyptus trees?",
     "answer": "The disease is caused by the fungus Puccinia psidii, which infects eucalyptus species."},
    {"question": "How can you control rust in barley?",
     "answer": "Use resistant varieties, remove crop residues, and apply fungicides."},
    {"question": "What are the symptoms of rust on pear trees?",
     "answer": "Rust causes yellow spots on the leaves, followed by the formation of orange pustules."},
    {"question": "How to manage rust in peas?",
     "answer": "Apply fungicides and remove infected leaves to prevent rust from spreading."},
    {"question": "What causes rust in alfalfa plants?",
     "answer": "Rust in alfalfa is caused by the fungus Uromyces striatus."},
    {"question": "How does rust affect the yield of rice?",
     "answer": "Rust reduces rice yield by causing premature leaf death, which weakens the plant."},
    {"question": "What is the main cause of rust on cabbage plants?",
     "answer": "The disease is caused by the fungus Puccinia brassicae, which infects cabbage leaves."},
    {"question": "How can rust be controlled in ginger plants?",
     "answer": "Remove infected leaves and apply fungicides containing copper or mancozeb."},
    {"question": "What are the symptoms of rust in tropical plants?",
     "answer": "Rust appears as yellow, orange, or red pustules on the underside of leaves."},
    {"question": "How to manage rust on lettuce?",
     "answer": "Remove infected leaves and apply fungicides like azoxystrobin."},
    {"question": "What causes rust in conifer trees?",
     "answer": "Rust on conifers is caused by the fungus Cronartium spp., which infects pine needles."},
    {"question": "What is the best preventive measure for rust on plants?",
     "answer": "Use rust-resistant varieties, maintain plant health, and apply fungicides as needed."},
    {"question": "How can you manage rust in potatoes?",
     "answer": "Apply fungicides early in the season and remove infected plant parts."},
    {"question": "What is the cause of rust in oak trees?",
     "answer": "Rust in oak trees is caused by the fungus Gymnosporangium spp., which affects oak leaves."},
    {"question": "What are the signs of rust in tomato plants?",
     "answer": "Rust causes brown, raised spots on the underside of leaves, and yellowing of the upper surface."},
    {"question": "What is Powdery Mildew?", "answer": "Powdery mildew is a fungal disease that affects many plants, characterized by white, powdery fungal growth on the leaves, stems, and buds."},
    {"question": "What causes Powdery Mildew?", "answer": "Powdery mildew is caused by various species of fungi in the order Erysiphales, such as Erysiphe cichoracearum and Sphaerotheca pannosa."},
    {"question": "How can Powdery Mildew be identified on plants?", "answer": "Powdery mildew can be identified by the presence of white, powdery spots on the leaves, stems, and flowers of the plant."},
    {"question": "What types of plants are affected by Powdery Mildew?", "answer": "Powdery mildew affects a wide variety of plants including vegetables, fruits, and ornamental plants like cucumbers, roses, and grapes."},
    {"question": "What are the symptoms of Powdery Mildew?", "answer": "Symptoms include white, powdery fungal growth on the upper sides of leaves, yellowing of leaves, stunted growth, and distorted plant parts."},
    {"question": "How does Powdery Mildew spread?", "answer": "Powdery mildew spreads through airborne spores, which can be carried by wind, insects, or contaminated equipment."},
    {"question": "Can Powdery Mildew kill plants?", "answer": "While Powdery Mildew rarely kills plants outright, severe infections can cause stunted growth, poor yields, and reduced vigor."},
    {"question": "How can Powdery Mildew be controlled?", "answer": "Powdery mildew can be controlled with fungicides, pruning infected areas, and increasing air circulation around plants."},
    {"question": "What are natural ways to control Powdery Mildew?", "answer": "Natural methods include using neem oil, garlic spray, and introducing beneficial insects like ladybugs to control fungal growth."},
    {"question": "How does Powdery Mildew affect the growth of plants?", "answer": "It reduces photosynthesis, causes leaf deformation, and weakens the plant's overall health, resulting in stunted growth."},
    {"question": "What environmental conditions favor Powdery Mildew?", "answer": "Powdery mildew thrives in warm, dry conditions with high humidity and poor air circulation."},
    {"question": "Can Powdery Mildew affect indoor plants?", "answer": "Yes, Powdery Mildew can affect indoor plants, especially in environments with poor air circulation and high humidity."},
    {"question": "Is Powdery Mildew more common in certain seasons?", "answer": "Yes, Powdery Mildew is most common in late spring and early summer when temperatures are warm, and humidity levels are moderate."},
    {"question": "Can Powdery Mildew be prevented?", "answer": "Preventative measures include proper plant spacing, choosing resistant plant varieties, and avoiding overhead watering."},
    {"question": "What fungicides are effective against Powdery Mildew?", "answer": "Fungicides containing sulfur, potassium bicarbonate, or neem oil are effective against Powdery Mildew."},
    {"question": "How often should plants be treated for Powdery Mildew?", "answer": "Treatment frequency depends on the severity of the infection, but typically every 7-14 days during the growing season."},
    {"question": "What are the effects of Powdery Mildew on fruit plants?", "answer": "On fruit plants, Powdery Mildew can affect fruit set, reduce quality, and cause premature fruit drop."},
    {"question": "Can Powdery Mildew infect trees?", "answer": "Yes, certain trees like roses, lilacs, and apple trees can be infected by Powdery Mildew, especially in humid conditions."},
    {"question": "What part of the plant is most affected by Powdery Mildew?", "answer": "Powdery mildew most commonly affects the upper surfaces of leaves but can also spread to stems, flowers, and buds."},
    {"question": "How can you tell if a plant has Powdery Mildew or other fungal diseases?", "answer": "Powdery Mildew is characterized by white, powdery spots, while other fungal diseases might cause dark spots or fuzzy growth."},
    {"question": "What is the lifecycle of Powdery Mildew?", "answer": "The lifecycle of Powdery Mildew involves the production of spores, which are spread by wind and land on suitable plant surfaces."},
    {"question": "How long does it take for Powdery Mildew to develop?", "answer": "Powdery Mildew can develop within a few days to a week under favorable conditions, depending on the plant and environmental factors."},
    {"question": "How does Powdery Mildew affect plant photosynthesis?", "answer": "The white fungal growth on leaves blocks sunlight, reducing photosynthesis and weakening the plant’s overall health."},
    {"question": "Is Powdery Mildew resistant to chemical treatments?", "answer": "Some strains of Powdery Mildew have developed resistance to certain fungicides, making it important to rotate treatments."},
    {"question": "Can Powdery Mildew be controlled organically?", "answer": "Yes, organic control methods include using sulfur-based fungicides, neem oil, and maintaining plant health through proper care."},
    {"question": "How can you reduce the spread of Powdery Mildew?", "answer": "To reduce spread, remove infected plant parts, avoid watering the leaves, and improve air circulation around plants."},
    {"question": "What is the ideal temperature for Powdery Mildew to thrive?", "answer": "Powdery Mildew thrives in temperatures between 60°F and 80°F (15°C to 27°C), with moderate humidity."},
    {"question": "Can Powdery Mildew affect vegetables?", "answer": "Yes, Powdery Mildew affects vegetables such as cucumbers, squash, and melons, reducing yield and quality."},
    {"question": "What is the first sign of Powdery Mildew infection?", "answer": "The first sign of Powdery Mildew infection is the appearance of white, powdery patches on the upper sides of leaves."},
    {"question": "What is the main cause of blight in tomato plants?",
     "answer": "Blight in tomato plants is caused by the fungus *Alternaria solani* or *Phytophthora infestans*."},
    {"question": "How can blight be prevented in potatoes?",
     "answer": "Blight in potatoes can be prevented by using fungicides and planting resistant varieties."},
    {"question": "What are the symptoms of late blight in tomatoes?",
     "answer": "Symptoms of late blight include water-soaked lesions on leaves, and dark, necrotic spots on stems and fruits."},
    {"question": "How does blight affect the yield of potato crops?",
     "answer": "Blight reduces potato yield by causing the plants to die prematurely and affecting the quality of tubers."},
    {"question": "What is the best time to apply fungicides for blight control?",
     "answer": "Fungicides should be applied early in the growing season, at the first signs of infection, and throughout the growing season."},
    {"question": "How does blight spread from plant to plant?",
     "answer": "Blight spreads through infected plant debris, spores carried by wind, rain, or through contaminated tools."},
    {"question": "What is the most common type of blight in tomatoes?",
     "answer": "Late blight caused by the fungus *Phytophthora infestans* is the most common and destructive type of blight in tomatoes."},
    {"question": "Can blight affect other crops besides tomatoes and potatoes?",
     "answer": "Yes, blight can also affect other crops like peppers, eggplants, and cucumbers."},
    {"question": "What are the visible symptoms of early blight in tomatoes?",
     "answer": "Early blight causes dark, concentric ring lesions on the leaves, and yellowing of the lower leaves."},
    {"question": "What environmental factors favor blight development?",
     "answer": "Cool, wet conditions with high humidity are ideal for the development of blight."},
    {"question": "How can blight-resistant varieties help in disease management?",
     "answer": "Blight-resistant varieties are bred to tolerate or resist infection by blight-causing pathogens."},
    {"question": "What are the potential consequences of untreated blight on crops?",
     "answer": "Untreated blight can lead to total crop loss, significantly affecting yields and quality."},
    {"question": "What is the role of crop rotation in controlling blight?",
     "answer": "Crop rotation helps prevent the buildup of blight pathogens in the soil by alternating crops that are not susceptible to the disease."},
    {"question": "Can blight be transmitted through contaminated seed?",
     "answer": "Yes, blight can be transmitted through infected seeds or planting material."},
    {"question": "How can irrigation practices affect blight spread?",
     "answer": "Irrigating from above with sprinklers can spread blight by splashing spores onto healthy plants."},
    {"question": "What are the common fungicides used to control blight in tomatoes?",
     "answer": "Common fungicides for blight control include copper-based fungicides and mancozeb."},
    {"question": "Is there a difference between early and late blight in potatoes?",
     "answer": "Yes, early blight affects older leaves, while late blight causes rapid, severe plant collapse and affects both leaves and tubers."},
    {"question": "How does blight affect the fruit of tomato plants?",
     "answer": "Blight causes dark, water-soaked lesions on the fruit, making it unmarketable."},
    {"question": "What are the key differences between early blight and late blight?",
     "answer": "Early blight shows concentric ring lesions on leaves, while late blight causes water-soaked lesions and rapid decay of the plant."},
    {"question": "What is the impact of high humidity on blight infections?",
     "answer": "High humidity creates an environment where spores can germinate and spread rapidly, promoting the growth of blight."},
    {"question": "Can blight be controlled by removing infected plant material?",
     "answer": "Yes, removing infected leaves, stems, and fruits helps reduce the spread of blight."},
    {"question": "What are the symptoms of blight on pepper plants?",
     "answer": "Blight on peppers causes wilting, leaf spots, and decaying fruits."},
    {"question": "How long can blight spores survive in the soil?",
     "answer": "Blight spores can survive in the soil for several months, especially in cool, moist conditions."},
    {"question": "What is the role of proper plant spacing in managing blight?",
     "answer": "Proper plant spacing allows for better air circulation, reducing the humidity that favors blight development."},
    {"question": "Can blight affect both the leaves and roots of a plant?",
     "answer": "Blight primarily affects the leaves and stems, but in severe cases, it can affect the roots and tubers."},
    {"question": "What is the ideal temperature for blight pathogens to thrive?",
     "answer": "Blight pathogens thrive in temperatures between 60-80°F (15-27°C)."},
     {"question": "What is Black Rot?", "answer": "Black Rot is a bacterial disease that affects many plants, particularly cabbage and other cruciferous vegetables, causing dark, decayed lesions on leaves and stems."},
    {"question": "What causes Black Rot?", "answer": "Black Rot is caused by the bacterium *Xanthomonas campestris* pv. *campestris*."},
    {"question": "How can Black Rot be identified?", "answer": "Black Rot can be identified by the presence of yellowing of the leaves, followed by the formation of dark, V-shaped lesions at the leaf margins."},
    {"question": "What types of plants are affected by Black Rot?", "answer": "Black Rot primarily affects cruciferous plants, including cabbage, cauliflower, broccoli, and other brassicas."},
    {"question": "What are the symptoms of Black Rot?", "answer": "Symptoms include yellowing of leaves, dark water-soaked lesions that spread inward from leaf margins, and blackening of veins."},
    {"question": "How does Black Rot spread?", "answer": "Black Rot spreads through contaminated seeds, plant debris, and water splash, often in wet conditions."},
    {"question": "Can Black Rot kill plants?", "answer": "Yes, Black Rot can kill plants if left uncontrolled, particularly during severe infections that affect the vascular system."},
    {"question": "How can Black Rot be controlled?", "answer": "Control measures include using disease-free seeds, crop rotation, proper spacing, and applying bactericides."},
    {"question": "What are natural ways to control Black Rot?", "answer": "Natural control methods include using resistant plant varieties, crop rotation, and managing irrigation to avoid water splashing on plants."},
    {"question": "How does Black Rot affect the growth of plants?", "answer": "Black Rot causes wilting, stunted growth, and reduced yields by damaging the plant's vascular system and preventing proper nutrient flow."},
    {"question": "What environmental conditions favor Black Rot?", "answer": "Black Rot thrives in warm, wet conditions, especially when there is overhead irrigation or rainfall that spreads the bacteria."},
    {"question": "Can Black Rot affect indoor plants?", "answer": "While less common in indoor plants, Black Rot can affect greenhouse crops, particularly if they are grown in humid, damp conditions."},
    {"question": "Is Black Rot more common in certain seasons?", "answer": "Yes, Black Rot is more common in warm, wet seasons, particularly during the spring and early summer when temperatures are moderate."},
    {"question": "Can Black Rot be prevented?", "answer": "Prevention involves using certified disease-free seeds, rotating crops, avoiding overhead irrigation, and removing infected plant debris."},
    {"question": "What bactericides are effective against Black Rot?", "answer": "Copper-based bactericides are commonly used to control Black Rot, though their effectiveness varies depending on the strain."},
    {"question": "How often should plants be treated for Black Rot?", "answer": "Treatment should be applied when symptoms are first observed and may need to be repeated every 7-10 days depending on the infection severity."},
    {"question": "What are the effects of Black Rot on fruit plants?", "answer": "Black Rot primarily affects the leaves and stems of plants but can indirectly affect fruit production by weakening the plant."},
    {"question": "Can Black Rot infect trees?", "answer": "Black Rot mainly affects cruciferous vegetables and is not typically a threat to trees, though some ornamental plants can be affected."},
    {"question": "What part of the plant is most affected by Black Rot?", "answer": "The most affected parts are the leaves and stems, where lesions appear and eventually cause the plant to wilt and die."},
    {"question": "How can you tell if a plant has Black Rot or other diseases?", "answer": "Black Rot is characterized by yellowing of leaves, dark lesions that spread inward from the leaf margins, and a water-soaked appearance."},
    {"question": "What is the lifecycle of Black Rot?", "answer": "The lifecycle of Black Rot involves bacterial spores that are spread by rain, wind, and infected plant material, infecting new plants through leaf wounds."},
    {"question": "How long does it take for Black Rot to develop?", "answer": "Black Rot can develop rapidly under favorable conditions, with symptoms appearing within a few days to a week after infection."},
    {"question": "How does Black Rot affect plant photosynthesis?", "answer": "The lesions caused by Black Rot reduce the surface area for photosynthesis, leading to stunted growth and reduced energy production for the plant."},
    {"question": "Is Black Rot resistant to chemical treatments?", "answer": "Some strains of *Xanthomonas campestris* are resistant to certain chemical treatments, making early intervention and crop rotation essential for control."},
    {"question": "Can Black Rot be controlled organically?", "answer": "Yes, organic methods include using biological control agents, copper-based products, and proper crop management practices to reduce the risk of infection."},
    {"question": "How can you reduce the spread of Black Rot?", "answer": "To reduce the spread, remove infected plant material, practice crop rotation, and avoid overhead irrigation that splashes bacteria onto healthy plants."},
    {"question": "What is the ideal temperature for Black Rot to thrive?", "answer": "Black Rot thrives in temperatures between 75°F and 85°F (24°C to 29°C), with high humidity and wet conditions."},
    {"question": "Can Black Rot affect vegetables?", "answer": "Yes, Black Rot primarily affects cabbage, cauliflower, and other brassica vegetables, causing significant yield losses."},
    {"question": "What is the first sign of Black Rot infection?", "answer": "The first sign of Black Rot is the appearance of yellowing at the leaf margins, followed by dark, V-shaped lesions that extend inward."},
    {"question": "What is Septoria Leaf Spot?", "answer": "Septoria Leaf Spot is a fungal disease caused by various species of the genus *Septoria*, affecting a wide range of plants, including tomatoes and potatoes."},
    {"question": "What causes Septoria Leaf Spot?", "answer": "Septoria Leaf Spot is caused by fungi in the *Septoria* genus, with common species being *Septoria lycopersici* and *Septoria bataticola*."},
    {"question": "How can Septoria Leaf Spot be identified?", "answer": "Septoria Leaf Spot can be identified by small, round or irregular-shaped lesions that are initially light in color and surrounded by dark edges."},
    {"question": "What types of plants are affected by Septoria Leaf Spot?", "answer": "Septoria Leaf Spot primarily affects tomatoes, potatoes, lettuce, and other vegetable crops, but can also affect ornamental plants."},
    {"question": "What are the symptoms of Septoria Leaf Spot?", "answer": "Symptoms include round, dark brown spots with yellow halos on leaves, followed by yellowing and eventual leaf death."},
    {"question": "How does Septoria Leaf Spot spread?", "answer": "Septoria Leaf Spot spreads through spores that are carried by wind, rain, or contaminated tools and equipment."},
    {"question": "Can Septoria Leaf Spot kill plants?", "answer": "While Septoria Leaf Spot rarely kills plants directly, severe infections can cause defoliation, reducing yields and weakening the plant."},
    {"question": "How can Septoria Leaf Spot be controlled?", "answer": "Control measures include applying fungicides, removing infected plant material, and practicing crop rotation."},
    {"question": "What are natural ways to control Septoria Leaf Spot?", "answer": "Natural methods include using organic fungicides like neem oil, improving plant spacing for better airflow, and removing infected plant parts."},
    {"question": "How does Septoria Leaf Spot affect the growth of plants?", "answer": "Septoria Leaf Spot weakens the plant by causing leaf damage, reducing photosynthesis, and limiting overall growth."},
    {"question": "What environmental conditions favor Septoria Leaf Spot?", "answer": "Septoria Leaf Spot thrives in wet, humid conditions, especially with frequent rain or overhead irrigation."},
    {"question": "Can Septoria Leaf Spot affect indoor plants?", "answer": "Yes, indoor plants, particularly those grown in humid environments, can also be affected by Septoria Leaf Spot."},
    {"question": "Is Septoria Leaf Spot more common in certain seasons?", "answer": "Yes, Septoria Leaf Spot is most common in wet, rainy seasons or during periods of high humidity."},
    {"question": "Can Septoria Leaf Spot be prevented?", "answer": "Prevention involves using disease-free seeds, removing infected plants, and improving plant spacing and airflow to reduce humidity."},
    {"question": "What fungicides are effective against Septoria Leaf Spot?", "answer": "Fungicides containing chlorothalonil, copper-based products, or mancozeb are commonly used to control Septoria Leaf Spot."},
    {"question": "How often should plants be treated for Septoria Leaf Spot?", "answer": "Fungicides should be applied every 7-10 days, especially during rainy or humid weather, to prevent the spread of Septoria Leaf Spot."},
    {"question": "What are the effects of Septoria Leaf Spot on fruit plants?", "answer": "Septoria Leaf Spot primarily affects leaves, but it can indirectly reduce fruit quality and yield by weakening the plant."},
    {"question": "Can Septoria Leaf Spot infect trees?", "answer": "Septoria Leaf Spot primarily affects herbaceous plants and vegetables, but some ornamental trees can also be susceptible."},
    {"question": "What part of the plant is most affected by Septoria Leaf Spot?", "answer": "The most affected parts are the leaves, where the characteristic lesions appear, leading to defoliation and stunted growth."},
    {"question": "How can you tell if a plant has Septoria Leaf Spot or other diseases?", "answer": "Septoria Leaf Spot is characterized by round, dark brown lesions with yellow halos, while other diseases may present with different types of spots or discoloration."},
    {"question": "What is the lifecycle of Septoria Leaf Spot?", "answer": "The lifecycle involves the production of spores on infected plant material, which are then spread by wind or rain to infect new plants."},
    {"question": "How long does it take for Septoria Leaf Spot to develop?", "answer": "Septoria Leaf Spot can develop rapidly under favorable conditions, with symptoms appearing within 5-7 days of infection."},
    {"question": "How does Septoria Leaf Spot affect plant photosynthesis?", "answer": "The lesions caused by Septoria Leaf Spot reduce the surface area for photosynthesis, which weakens the plant and reduces its energy production."},
    {"question": "Is Septoria Leaf Spot resistant to chemical treatments?", "answer": "Some strains of *Septoria* may show partial resistance to certain fungicides, making crop rotation and integrated pest management important."},
    {"question": "Can Septoria Leaf Spot be controlled organically?", "answer": "Yes, organic control methods include using copper-based fungicides, applying neem oil, and practicing proper crop management techniques."},
    {"question": "How can you reduce the spread of Septoria Leaf Spot?", "answer": "To reduce spread, remove infected leaves and debris, avoid overhead watering, and maintain good plant spacing for airflow."},
    {"question": "What is the ideal temperature for Septoria Leaf Spot to thrive?", "answer": "Septoria Leaf Spot thrives in temperatures between 70°F and 85°F (21°C to 29°C), with high humidity or frequent rain."},
    {"question": "Can Septoria Leaf Spot affect vegetables?", "answer": "Yes, Septoria Leaf Spot commonly affects vegetables like tomatoes, lettuce, and potatoes, causing significant damage to leaves."},
    {"question": "What is the first sign of Septoria Leaf Spot infection?", "answer": "The first sign is the appearance of small, round, water-soaked lesions with yellow halos, which expand and darken as the disease progresses."},

])
df = pd.DataFrame(plant_disease_data)

df.to_csv('plant_disease_data.csv', index=False, encoding='utf-8')
print("Dataset berhasil disimpan dalam bentuk CSV!")

# %% [markdown]
# # Load Dataset

# %%
from datasets import load_dataset
# Memuat dataset dari file CSV
dataset = load_dataset('csv', data_files='plant_disease_data.csv')

data = dataset['train'].train_test_split(test_size=0.3)
# Menampilkan beberapa contoh data
print(data)

# %% [markdown]
# # Make function Pre propcessing

# %%
prefix = "answer this question:"
def preprocess_function(examples):
   """Add prefix to the sentences, tokenize the text, and set the labels"""
   # The "inputs" are the tokenized answer:
   inputs = [prefix+doc for doc in examples["question"]]
   model_inputs = tokenizer(inputs, max_length=128, truncation=True)

   # The "labels" are the tokenized outputs:
   labels = tokenizer(text_target=examples["answer"],
                      max_length=512,
                      truncation=True)

   model_inputs["labels"] = labels["input_ids"]
   return model_inputs

# %% [markdown]
# # Load Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, DataCollatorForSeq2Seq

MODEL_NAME = "google/flan-t5-base"

tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
tokenized_dataset = data.map(preprocess_function, batched=True)

# %% [markdown]
# # Make Matric Rogue

# %%
import nltk
from evaluate import load
nltk.download('punkt')
nltk.download('punkt_tab')
# Memuat metrik evaluasi ROUGE
metric = load("rouge")

# %%
import numpy as np
def compute_metrics(eval_preds):
   preds, labels = eval_preds

   # decode preds and labels
   labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
   decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
   decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

   # rougeLSum expects newline after each sentence
   decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
   decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]

   result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

   return result

# %% [markdown]
# # Make code For Fine Tunning

# %%
from transformers import Seq2SeqTrainingArguments
# Global Parameters
L_RATE = 3e-4
BATCH_SIZE = 8
PER_DEVICE_EVAL_BATCH = 8
WEIGHT_DECAY = 0.01
SAVE_TOTAL_LIM = 3
NUM_EPOCHS = 3

# Set up training arguments
training_args = Seq2SeqTrainingArguments(
   output_dir="./results",
   evaluation_strategy="epoch",
   learning_rate=L_RATE,
   per_device_train_batch_size=BATCH_SIZE,
   per_device_eval_batch_size=PER_DEVICE_EVAL_BATCH,
   weight_decay=WEIGHT_DECAY,
   save_total_limit=SAVE_TOTAL_LIM,
   num_train_epochs=NUM_EPOCHS,
   predict_with_generate=True,
   push_to_hub=False,
   logging_dir="./logs",  # Direktori log
   logging_steps=10
)

# %% [markdown]
# # Train

# %%
from transformers import Seq2SeqTrainer
trainer = Seq2SeqTrainer(
   model=model,
   args=training_args,
   train_dataset=tokenized_dataset["train"],
   eval_dataset=tokenized_dataset["test"],
   tokenizer=tokenizer,
   data_collator=data_collator,
   compute_metrics=compute_metrics
)
# Out:
# <ipython-input-10-2d5b1280849a>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %%
trainer.train()

# %% [markdown]
# # Load Model from result Fine Tuning

# %%
last_checkpoint = "./results/checkpoint-42"

finetuned_model = T5ForConditionalGeneration.from_pretrained(last_checkpoint)
tokenizer = T5Tokenizer.from_pretrained(last_checkpoint)

# %% [markdown]
# # Try Model with give input

# %%
my_question = "What part of the plant is most affected by Powdery Mildew?"
inputs = "answer to this question: " + my_question

# %%
inputs = tokenizer(my_question, return_tensors="pt")

# Tambahkan parameter untuk mengontrol panjang jawaban
outputs = finetuned_model.generate(
    **inputs,
    max_length=150,         # Atur panjang maksimal
    min_length=50,         # Atur panjang minimal
    length_penalty=0.8,     # Dorong model untuk memberikan jawaban lebih panjang
    no_repeat_ngram_size=3, # Hindari pengulangan frasa
    temperature=0.7,        # Dorong variasi dalam output
    top_p=0.9               # Gunakan sampling untuk diversifikasi
)

answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
from textwrap import fill

print(fill(answer, width=80))
